# %%
import numpy as np

# %%
-(9/14)*np.log2(9/14)-(5/14)*np.log2(5/14)
# Out:
# np.float64(0.9402859586706311)

# %%
np.log2(5)
# Out:
# np.float64(2.321928094887362)

# %%
round(-(2/5)*np.log2(2/5)-(3/5)*np.log2(3/5) , 6)
# Out:
# np.float64(0.970951)

# %%
np.log2(1)
# Out:
# np.float64(0.0)

# %%
0.9402859586706311 -  ((5/14)*0.970951 + 0 + \
(5/14)*0.970951)
# Out:
# 0.24674953009920253

# %%
 -(2/4*np.log2(0.5))- (2/4*np.log2(0.5))
# Out:
# np.float64(1.0)

# %%
 -(4/6*np.log2(4/6))- (2/6*np.log2(2/6))
# Out:
# np.float64(0.9182958340544896)

# %%
 -(3/4*np.log2(3/4))- (1/4*np.log2(1/4))
# Out:
# np.float64(0.8112781244591328)

# %%
#  IG  for temp
0.9402859586706311- (4/14 + 6/14*0.9182958 +4/14*0.811278)
# Out:
# 0.029222615813488284

# %%
 -3/7*np.log2(3/7)- (4/7*np.log2(4/7))
# Out:
# np.float64(0.9852281360342515)

# %%
 -(6/7*np.log2(6/7))- (1/7*np.log2(1/7))
# Out:
# np.float64(0.5916727785823275)

# %%
0.9402859586706311-(1/2*0.98522813+1/2*0.5916727)
# Out:
# 0.15183554367063112

# %%
 -(6/8*np.log2(6/8))- (2/8*np.log2(2/8))
# Out:
# np.float64(0.8112781244591328)

# %%
0.9402859586706311-(6/14*1+8/14*0.8112781244591328)
# Out:
# 0.04812703040826949

# %%
 a  =  [62   ,  55 , 78  , 89 , 85 ,78  ,      73    ]
